# %%
cd drive/MyDrive/MachineTranslation/
# Out:
# /content/drive/MyDrive/MachineTranslation

# %%
# !pip install pyvi torchtext

# %%
from pyvi import ViPosTagger 
ViPosTagger.postagging("Chào Hiểu, câu đang làm gì vậy hả Bình 29/11")

# %%
# !python preprocess.py

# %%
# !python training.py

# %%
# !python evaluate.py
